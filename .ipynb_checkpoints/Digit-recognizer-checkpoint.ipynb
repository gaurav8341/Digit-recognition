# %%
import numpy as np 
import pandas as pd 
import torch
import torch.nn as nn
import torchvision.transforms as transforms
from sklearn.model_selection import train_test_split

# %%
train = pd.read_csv(r'train.csv', dtype = np.float32) 

targets_np = train.label.values
features_np = train.loc[: , train.columns != 'label'].values / 255 #normalization

features_train , features_test , target_train, target_test = train_test_split(features_np,targets_np, 
                                                                              test_size = 0.2, random_state = 42)
featuresTrain = torch.from_numpy(features_train)
targetsTrain = torch.from_numpy(target_train).type(torch.LongTensor)

featuresTest = torch.from_numpy(features_test)
targetsTest = torch.from_numpy(target_test).type(torch.LongTensor)

batch_size = 100
n_iter = 15000
n_epochs = int(n_iter/(len(features_train) / batch_size )) 

Train = torch.utils.data.TensorDataset(featuresTrain , targetsTrain)
Test = torch.utils.data.TensorDataset(featuresTest , targetsTest)

TrainLoader = torch.utils.data.DataLoader(Train , batch_size = batch_size , shuffle = False)
TestLoader = torch.utils.data.DataLoader(Test , batch_size = batch_size , shuffle = False)

# %%
from torch import nn, optim
import torch.nn.functional as F
class Classifier(nn.Module):
    def __init__(self):
        super().__init__()
        
        self.fc1 = nn.Linear(784 , 256)
        self.fc2 = nn.Linear(256 , 128)
        self.fc3 = nn.Linear(128 ,64)
        self.fc4 = nn.Linear(64 , 10)
        self.dropout = nn.Dropout(p = 0.2)
        
    def forward(self , x):
        x = x.view(x.shape[0], -1)
        x = self.dropout(F.relu(self.fc1(x)))
        x = self.dropout(F.relu(self.fc2(x)))
        x = self.dropout(F.relu(self.fc3(x)))
        
        x = torch.sigmoid(self.fc4(x))
        
        return x

# %%
model = Classifier()
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters() , lr = 0.3)

test_losses = []
train_losses = []
accuracy_list = []
iteration_list = []
count = 0
for e in range(n_epochs):
    #print('Epoch {}/{}'.format(e , n_epochs))
    running_loss = 0
    for images , labels in TrainLoader:
        images = images.view( images.shape[0],-1)
        
        optimizer.zero_grad()
        output = model(images)
        loss = criterion(output, labels)
        loss.backward()
        optimizer.step()
        count += 1
        running_loss += loss.item()
        
        
    else:
        test_loss = 0;
        accuracy = 0
        with torch.no_grad():
            model.eval()
            for images , labels in TestLoader:
                images = images.view(images.shape[0] , -1)
                output = model(images)
                test_loss += criterion(output,labels)
                
                predicted = torch.max(output.data ,1 )[1]
                
                equals = predicted == labels
                accuracy += torch.mean(equals.type(torch.FloatTensor)) 
            
            model.train()
            
            
            train_losses.append(running_loss/len(TrainLoader))
            test_losses.append(test_loss/len(TestLoader))
            accuracy_list.append(accuracy/len(TestLoader))
            iteration_list.append(count)
           
           
            print("Epoch: {}/{}".format(e+1 , n_epochs),
                "Iteration: {}..".format(iteration_list[-1]),
                 "Training Loss: {:.3f}.. ".format(train_losses[-1]),
                 "Test Loss: {:.3f}.. ".format(test_losses[-1]),
                 "Test Accuracy: {:.3f}".format(accuracy_list[-1] ))
            
print('training Completed');
# Out:
# Epoch: 1/44 Iteration: 336.. Training Loss: 2.059..  Test Loss: 1.765..  Test Accuracy: 0.694
# Epoch: 2/44 Iteration: 672.. Training Loss: 1.712..  Test Loss: 1.642..  Test Accuracy: 0.781
# Epoch: 3/44 Iteration: 1008.. Training Loss: 1.630..  Test Loss: 1.590..  Test Accuracy: 0.868
# Epoch: 4/44 Iteration: 1344.. Training Loss: 1.588..  Test Loss: 1.562..  Test Accuracy: 0.873
# Epoch: 5/44 Iteration: 1680.. Training Loss: 1.568..  Test Loss: 1.550..  Test Accuracy: 0.867
# Epoch: 6/44 Iteration: 2016.. Training Loss: 1.554..  Test Loss: 1.533..  Test Accuracy: 0.918
# Epoch: 7/44 Iteration: 2352.. Training Loss: 1.539..  Test Loss: 1.525..  Test Accuracy: 0.926
# Epoch: 8/44 Iteration: 2688.. Training Loss: 1.530..  Test Loss: 1.519..  Test Accuracy: 0.932
# Epoch: 9/44 Iteration: 3024.. Training Loss: 1.522..  Test Loss: 1.513..  Test Accuracy: 0.939
# Epoch: 10/44 Iteration: 3360.. Training Loss: 1.517..  Test Loss: 1.508..  Test Accuracy: 0.945
# Epoch: 11/44 Iteration: 3696.. Training Loss: 1.512..  Test Loss: 1.506..  Test Accuracy: 0.948
# Epoch: 12/44 Iteration: 4032.. Training Loss: 1.509..  Test Loss: 1.502..  Test Accuracy: 0.951
# Epoch: 13/44 Iteration: 4368.. Training Loss: 1.505..  Test Loss: 1.500..  Test Accuracy: 0.954
# Epoch: 14/44 Iteration: 4704.. Training Loss: 1.502..  Test Loss: 1.498..  Test Accuracy: 0.957
# Epoch: 15/44 Iteration: 5040.. Training Loss: 1.499..  Test Loss: 1.498..  Test Accuracy: 0.956
# Epoch: 16/44 Iteration: 5376.. Training Loss: 1.497..  Test Loss: 1.497..  Test Accuracy: 0.959
# Epoch: 17/44 Iteration: 5712.. Training Loss: 1.495..  Test Loss: 1.494..  Test Accuracy: 0.964
# Epoch: 18/44 Iteration: 6048.. Training Loss: 1.493..  Test Loss: 1.493..  Test Accuracy: 0.963
# Epoch: 19/44 Iteration: 6384.. Training Loss: 1.492..  Test Loss: 1.492..  Test Accuracy: 0.965
# Epoch: 20/44 Iteration: 6720.. Training Loss: 1.489..  Test Loss: 1.490..  Test Accuracy: 0.965
# Epoch: 21/44 Iteration: 7056.. Training Loss: 1.489..  Test Loss: 1.489..  Test Accuracy: 0.967
# Epoch: 22/44 Iteration: 7392.. Training Loss: 1.488..  Test Loss: 1.490..  Test Accuracy: 0.966
# Epoch: 23/44 Iteration: 7728.. Training Loss: 1.486..  Test Loss: 1.489..  Test Accuracy: 0.968
# Epoch: 24/44 Iteration: 8064.. Training Loss: 1.485..  Test Loss: 1.488..  Test Accuracy: 0.969
# Epoch: 25/44 Iteration: 8400.. Training Loss: 1.484..  Test Loss: 1.488..  Test Accuracy: 0.969
# Epoch: 26/44 Iteration: 8736.. Training Loss: 1.483..  Test Loss: 1.487..  Test Accuracy: 0.969
# Epoch: 27/44 Iteration: 9072.. Training Loss: 1.482..  Test Loss: 1.486..  Test Accuracy: 0.970
# Epoch: 28/44 Iteration: 9408.. Training Loss: 1.482..  Test Loss: 1.486..  Test Accuracy: 0.970
# Epoch: 29/44 Iteration: 9744.. Training Loss: 1.480..  Test Loss: 1.485..  Test Accuracy: 0.971
# Epoch: 30/44 Iteration: 10080.. Training Loss: 1.479..  Test Loss: 1.485..  Test Accuracy: 0.972
# Epoch: 31/44 Iteration: 10416.. Training Loss: 1.480..  Test Loss: 1.485..  Test Accuracy: 0.973
# Epoch: 32/44 Iteration: 10752.. Training Loss: 1.479..  Test Loss: 1.485..  Test Accuracy: 0.972
# Epoch: 33/44 Iteration: 11088.. Training Loss: 1.479..  Test Loss: 1.484..  Test Accuracy: 0.974
# Epoch: 34/44 Iteration: 11424.. Training Loss: 1.478..  Test Loss: 1.484..  Test Accuracy: 0.973
# Epoch: 35/44 Iteration: 11760.. Training Loss: 1.477..  Test Loss: 1.484..  Test Accuracy: 0.972
# Epoch: 36/44 Iteration: 12096.. Training Loss: 1.477..  Test Loss: 1.484..  Test Accuracy: 0.974
# Epoch: 37/44 Iteration: 12432.. Training Loss: 1.476..  Test Loss: 1.484..  Test Accuracy: 0.974
# Epoch: 38/44 Iteration: 12768.. Training Loss: 1.476..  Test Loss: 1.484..  Test Accuracy: 0.974
# Epoch: 39/44 Iteration: 13104.. Training Loss: 1.476..  Test Loss: 1.483..  Test Accuracy: 0.974
# Epoch: 40/44 Iteration: 13440.. Training Loss: 1.475..  Test Loss: 1.483..  Test Accuracy: 0.974
# Epoch: 41/44 Iteration: 13776.. Training Loss: 1.475..  Test Loss: 1.483..  Test Accuracy: 0.974
# Epoch: 42/44 Iteration: 14112.. Training Loss: 1.474..  Test Loss: 1.483..  Test Accuracy: 0.974
# Epoch: 43/44 Iteration: 14448.. Training Loss: 1.474..  Test Loss: 1.483..  Test Accuracy: 0.976
# Epoch: 44/44 Iteration: 14784.. Training Loss: 1.474..  Test Loss: 1.482..  Test Accuracy: 0.975
# training Completed

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt

plt.plot(iteration_list,test_losses , color = 'brown')
plt.xlabel("Number of iteration")
plt.ylabel("Loss")
plt.title("ANN: Loss vs Number of iteration")
plt.show()

# visualization accuracy 
plt.plot(iteration_list , accuracy_list,color = "red")
plt.xlabel("Number of iteration")
plt.ylabel("Accuracy")
plt.title("ANN: Accuracy vs Number of iteration")
plt.show()

plt.plot(train_losses, label='Training loss')
plt.plot(test_losses, label='Validation loss')
plt.xlabel("Number of Epochs")
plt.ylabel("Loss")
plt.title("ANN: Loss vs Number of Epochs")
plt.legend(frameon = False)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
test = pd.read_csv('test.csv')
x_test = test.values
x_test = x_test.reshape([-1, 28, 28]).astype(float)
x_test = x_test / 255
x_test = torch.from_numpy(np.float32(x_test))
x_test.shape
# Out:
# torch.Size([28000, 28, 28])

# %%
model.eval()
pred = model(x_test.float())
pred = torch.argmax(pred, 1)
print('Prediction: ', pred)
# Out:
# Prediction:  tensor([2, 0, 9,  ..., 3, 9, 2])

# %%
def export_csv(model_name, predictions):
    df = pd.DataFrame(predictions.tolist(), columns=['Label'])
    df['ImageId'] = df.index + 1
    file_name = f'submission_{model_name}.csv'
    print('Saving ',file_name)
    df[['ImageId','Label']].to_csv(file_name, index = False)

# %%
export_csv('model',pred)
torch.save(model.state_dict(), 'model.ckpt')
# Out:
# Saving  submission_model.csv

# %%
model.state_dict()
# Out:
# OrderedDict([('fc1.weight',
#               tensor([[-0.0103, -0.0011, -0.0310,  ...,  0.0201,  0.0289,  0.0314],
#                       [-0.0074, -0.0218, -0.0075,  ...,  0.0013,  0.0038,  0.0051],
#                       [-0.0125, -0.0176, -0.0110,  ...,  0.0021,  0.0141, -0.0110],
#                       ...,
#                       [ 0.0173, -0.0030, -0.0049,  ..., -0.0232,  0.0337, -0.0322],
#                       [ 0.0302,  0.0315,  0.0193,  ..., -0.0036, -0.0225,  0.0096],
#                       [ 0.0191,  0.0341,  0.0032,  ..., -0.0086,  0.0218, -0.0052]])),
#              ('fc1.bias',
#               tensor([-7.0037e-02,  3.9730e-02,  1.1982e-01,  2.9397e-02, -1.3021e-02,
#                        1.8387e-02, -2.8701e-02,  2.3816e-02, -2.5060e-03,  6.3885e-03,
#                       -5.9278e-02, -3.8626e-02, -9.4714e-03,  8.6655e-03, -4.6272e-02,
#                       -3.1464e-02,  3.0889e-02, -4.8184e-03, -7.0410e-02, -5.8923e-02,
#                        3.2441e-02, -2.0425e-02, -1.3043e-01,  1.1746e-02, -4.3590e-02,
#                       -2.1573e-02, -6.5351e-03,  8.1588e-02, -5.9863e-02,  5.7337e-02,
#                       -1.0649e-01,  1.3003e-01, -5.6702e-02,  1.2547e-01, -9.3783e-02,
#                       -3.1854e-02,  9.7047e-02, -8.1955e-02,  4.7816e-02, -1.1940e-02,
#                       -3.3564e-02, -1.3117e-01,  3.7484e-02, -1.4538e-01, -1.3057e-02,
#                       -4.4432e-03,  2.0831e-02, -1.0393e-01, -6.1263e-02, -1.1637e-01,
#                        4.9195e-02,  2.2289e-02, -2.9839e-03, -2.2321e-03,  3.0043e-02,
#                        3.4133e-02,  6.9729e-02, -7.1365e-02,  2.8950e-02, -7.5572e-02,
#                        3.0540e-02, -5.3231e-02,  5.7282e-03,  4.5810e-02, -1.0464e-01,
#                       -2.4028e-02, -9.2830e-02,  8.3005e-02,  1.0533e-01,  2.1028e-02,
#                       -1.5265e-01,  6.0222e-02, -9.1695e-02, -5.8534e-03,  2.0602e-02,
#                       -1.4315e-01, -5.7587e-02, -1.0102e-01,  3.7580e-02,  1.2068e-02,
#                        1.4463e-01, -2.0774e-03, -8.1217e-02,  3.2777e-02, -7.5290e-02,
#                       -4.2585e-03,  1.6428e-02,  2.7583e-02, -3.4445e-02, -1.5460e-02,
#                        5.2118e-04, -2.1543e-02,  1.6597e-02,  2.5725e-02, -1.5496e-02,
#                       -2.2674e-02, -8.5403e-02, -9.6152e-03, -4.2639e-02,  1.9498e-02,
#                       -9.4178e-02,  3.3011e-02, -1.3137e-02,  4.0421e-02,  9.2052e-02,
#                       -7.8873e-02, -1.3228e-01, -9.1492e-02, -1.2935e-01, -9.2597e-04,
#                       -1.7376e-01,  2.9778e-03, -8.8293e-02,  2.1249e-03,  6.9233e-02,
#                       -2.7267e-02, -4.8507e-02, -3.2963e-03, -2.6527e-02, -4.0082e-03,
#                       -1.1960e-02,  6.2766e-02, -2.6780e-02, -4.6370e-02,  4.0807e-02,
#                       -1.0967e-02,  3.3393e-02,  1.4497e-02, -6.4595e-03,  1.8071e-02,
#                        3.3042e-02, -6.2302e-02, -6.6220e-02,  1.9172e-02, -6.3136e-03,
#                       -6.5639e-02, -1.7214e-04, -2.5900e-02, -1.1694e-01,  5.9241e-02,
#                       -6.0974e-02, -1.1654e-02, -5.3080e-02, -3.7108e-02, -1.0712e-01,
#                       -2.1390e-02, -2.2415e-02, -6.2423e-02,  2.1920e-02, -7.9704e-02,
#                        5.4287e-03, -4.7225e-02,  6.7710e-02,  1.1313e-02, -5.1996e-03,
#                        6.7979e-02, -5.9924e-03,  3.7799e-02, -5.1986e-02, -1.4875e-01,
#                        1.6913e-02,  5.7761e-03,  3.9203e-02, -9.1041e-03, -2.6276e-02,
#                       -5.8207e-02,  3.2008e-02,  5.0491e-02, -7.0614e-03,  5.6782e-02,
#                       -2.3891e-02,  6.3563e-02, -7.2808e-02, -5.5465e-02,  6.1210e-02,
#                        2.0993e-02, -1.5603e-01, -5.4379e-02,  1.1741e-03, -1.9565e-02,
#                       -9.8602e-03, -7.2836e-03,  1.9308e-02,  1.1129e-02,  1.1542e-01,
#                        4.2918e-02, -2.0642e-02, -2.3184e-02, -1.0562e-01, -5.8193e-02,
#                       -3.4748e-02,  8.3316e-03, -2.4545e-02,  6.4419e-02,  3.6185e-02,
#                       -8.9963e-02, -1.9677e-02,  8.1265e-02,  2.3122e-02, -3.2317e-02,
#                       -1.1961e-01,  1.2362e-02,  5.7523e-02, -1.2840e-02, -3.1947e-02,
#                       -9.2951e-02, -7.9434e-02,  5.3521e-02, -7.1169e-02,  1.2078e-02,
#                       -7.3168e-02, -1.5849e-01,  1.5332e-02, -4.2059e-02, -1.5420e-02,
#                        1.8398e-01, -2.9638e-02, -1.0010e-01, -7.1036e-02,  3.9961e-02,
#                        1.7129e-01, -2.3115e-03, -8.7392e-03, -1.6865e-02,  1.0274e-01,
#                       -5.8584e-02, -1.5360e-02,  1.3750e-02, -5.0464e-02, -5.1773e-02,
#                       -2.1084e-02,  1.1744e-01,  4.8408e-02,  2.0211e-02, -5.1113e-02,
#                        8.0255e-02,  2.4245e-02, -2.9139e-02,  1.7020e-02,  2.4551e-03,
#                       -2.0229e-02,  2.9633e-03, -4.5541e-02,  5.1055e-03,  5.5689e-02,
#                       -2.6955e-02,  2.6066e-02, -4.2366e-03,  1.3156e-02,  1.1495e-01,
#                        4.9962e-03, -4.1901e-02,  4.6749e-02, -1.8930e-01,  9.3938e-02,
#                        5.1507e-02])),
#              ('fc2.weight',
#               tensor([[-0.0481, -0.0764, -0.0139,  ..., -0.0764,  0.0352, -0.0062],
#                       [-0.0557,  0.0464, -0.1177,  ...,  0.0814,  0.0403, -0.0589],
#                       [ 0.0242, -0.1015, -0.1626,  ...,  0.0161,  0.0017,  0.0066],
#                       ...,
#                       [ 0.0553, -0.0524, -0.0179,  ..., -0.1278,  0.0191,  0.0073],
#                       [-0.0294, -0.0320,  0.0501,  ..., -0.0763, -0.0621, -0.0275],
#                       [-0.0581,  0.0778, -0.0839,  ...,  0.0463, -0.0744, -0.1996]])),
#              ('fc2.bias',
#               tensor([ 0.0837,  0.0478,  0.0478, -0.0161,  0.1286, -0.0053,  0.1324,  0.1148,
#                        0.1266,  0.0706,  0.0403,  0.0451,  0.0030, -0.0158,  0.0677,  0.0427,
#                        0.0608,  0.0758, -0.0694, -0.0550,  0.0851,  0.0575,  0.1032,  0.0495,
#                       -0.0343, -0.0053,  0.0417,  0.0770,  0.0454, -0.0158,  0.1252, -0.0222,
#                        0.0814,  0.0774,  0.0866,  0.0048, -0.0259,  0.0382,  0.0913, -0.0043,
#                       -0.0467,  0.0794,  0.0486,  0.0058,  0.1228, -0.0340,  0.0116,  0.0578,
#                        0.0433,  0.0297, -0.0188, -0.0036,  0.0699,  0.1160,  0.0510,  0.0416,
#                        0.0760,  0.0252,  0.1047,  0.0701, -0.0398,  0.0049, -0.0458,  0.0166,
#                        0.0253, -0.0302, -0.0334, -0.0403, -0.0248,  0.0636,  0.0675, -0.0271,
#                       -0.0548,  0.0672, -0.0035,  0.0258, -0.0291, -0.0137,  0.0008,  0.0771,
#                        0.0892,  0.1076,  0.0284,  0.0460,  0.0826,  0.0463,  0.0696,  0.0306,
#                        0.0150,  0.0205, -0.0536,  0.0939, -0.0404,  0.0796,  0.0451,  0.0850,
#                        0.0045,  0.0836,  0.0797,  0.0325, -0.0529,  0.1663,  0.0349,  0.0179,
#                        0.0217,  0.0079,  0.0485,  0.0894,  0.0912,  0.0830, -0.0014,  0.0921,
#                       -0.0329, -0.0275,  0.0979,  0.0614,  0.0236,  0.0693, -0.0145,  0.0007,
#                        0.1044, -0.0632,  0.0429,  0.0874,  0.1097, -0.0192, -0.0274, -0.0141])),
#              ('fc3.weight',
#               tensor([[-0.1278,  0.2147, -0.0679,  ..., -0.0870,  0.0791,  0.1614],
#                       [ 0.0098,  0.1736,  0.1350,  ..., -0.1077,  0.0083,  0.0008],
#                       [ 0.0742, -0.1375,  0.0157,  ..., -0.1040, -0.1087, -0.1747],
#                       ...,
#                       [-0.1100,  0.0196,  0.1650,  ..., -0.0527,  0.0353,  0.0450],
#                       [-0.0447, -0.0805,  0.0358,  ..., -0.1328, -0.0086, -0.1084],
#                       [ 0.2873,  0.3704, -0.0392,  ..., -0.1878, -0.1457,  0.1657]])),
#              ('fc3.bias',
#               tensor([ 0.0241,  0.0363,  0.0785, -0.0115,  0.1448,  0.0259, -0.0054, -0.0227,
#                       -0.0438,  0.0167,  0.0323, -0.0218, -0.0133,  0.1451, -0.0601, -0.0573,
#                       -0.0417, -0.0643,  0.1163,  0.0407,  0.0431, -0.0321,  0.0147, -0.0706,
#                        0.0476,  0.0713, -0.0595,  0.0004, -0.0158, -0.0108, -0.0381, -0.0429,
#                       -0.0232,  0.0562,  0.1421,  0.1106,  0.0029,  0.1504, -0.0032, -0.0795,
#                       -0.0625,  0.0717, -0.0730,  0.0534,  0.0502,  0.1077,  0.0093, -0.0459,
#                       -0.0421,  0.0576, -0.0006,  0.1072, -0.0560,  0.2284, -0.0333,  0.1746,
#                       -0.0309, -0.0172,  0.0477, -0.0271, -0.0987,  0.0599, -0.0226,  0.0672])),
#              ('fc4.weight',
#               tensor([[-6.4638e-01, -1.6744e-01,  3.5197e-01,  6.3212e-02, -6.7795e-02,
#                        -1.9076e-01, -4.0646e-02, -3.8241e-01, -1.6326e-02,  1.1959e-01,
#                        -6.0703e-01,  7.9763e-02,  2.4669e-01, -1.5263e-03,  1.9988e-01,
#                        -8.9575e-02, -4.9484e-03,  8.2830e-02, -3.1254e-01, -3.0955e-01,
#                        -4.8870e-01,  2.5243e-01,  6.7907e-02, -2.0475e-02, -7.4237e-01,
#                        -1.0784e-02,  3.4997e-03,  7.7144e-02, -7.1594e-01,  8.2508e-02,
#                         1.0785e-01, -1.1194e-01, -2.2354e-01, -9.8730e-02, -6.8836e-01,
#                         5.2909e-02, -3.1461e-01, -4.8080e-01,  3.9942e-02, -8.3671e-02,
#                        -1.0935e-01,  3.3330e-01,  1.0612e-01,  2.1428e-01, -7.0062e-01,
#                        -3.2531e-01, -6.0478e-01,  2.5189e-02,  2.7921e-01, -6.6713e-01,
#                        -8.6821e-01, -6.8278e-01,  1.2376e-01, -4.5761e-01, -7.2804e-01,
#                        -5.3650e-01, -7.5363e-01, -6.7319e-02,  2.3452e-01, -4.5302e-02,
#                         2.5507e-01,  2.8695e-01, -5.0004e-02, -7.1282e-01],
#                       [ 2.8149e-01,  2.9209e-02, -2.2593e-01, -5.4190e-01,  3.5733e-01,
#                        -4.3688e-01, -6.1579e-01, -4.0754e-01, -1.4675e-02, -3.2228e-01,
#                        -6.0022e-02, -1.2199e-01, -2.7538e-01,  4.7250e-01, -1.9447e-01,
#                        -3.5262e-01, -5.4494e-01, -4.4301e-01,  4.2353e-01, -2.4299e-01,
#                        -4.4158e-01, -4.8731e-01, -2.6705e-01, -7.7083e-01,  3.4277e-02,
#                        -2.6663e-02, -9.1154e-02, -1.2725e-01, -5.6275e-03, -4.0830e-01,
#                        -7.1820e-01,  5.6102e-02,  4.1919e-02,  1.7081e-01,  3.1898e-01,
#                        -1.4701e-01,  2.5834e-01, -5.6455e-01,  3.2869e-01, -2.3989e-01,
#                        -2.2329e-01,  1.2590e-02, -4.3348e-01, -1.2672e-01, -4.6844e-01,
#                        -4.4508e-01, -1.2401e-01, -6.0330e-01, -3.0397e-01, -1.6530e-01,
#                         5.0704e-02, -6.6647e-01, -4.1613e-02,  3.8768e-01,  2.2944e-01,
#                        -5.0291e-01, -1.4737e-02,  4.1531e-01, -4.7052e-01, -5.8132e-01,
#                        -1.8392e-01, -6.0381e-01, -8.7845e-02,  4.0998e-01],
#                       [ 1.1760e-01, -5.4875e-01, -1.4927e-01,  8.8522e-02, -1.8187e-01,
#                        -7.2124e-01, -4.7005e-01, -2.4500e-01,  9.2418e-02,  1.1383e-01,
#                        -7.5571e-01, -2.0170e-02, -4.7494e-01, -2.6265e-01,  2.1900e-01,
#                        -2.8133e-01, -3.4506e-01,  9.9701e-02, -4.9094e-01,  5.0987e-02,
#                         2.0227e-01, -7.6316e-01,  2.0304e-01, -7.9277e-02,  5.1067e-02,
#                         2.2934e-01, -4.3420e-02,  1.1689e-01,  1.0101e-01, -5.9581e-01,
#                        -4.0183e-01,  2.3753e-04, -8.6117e-02,  1.2295e-01, -6.5584e-01,
#                        -5.4561e-01,  2.1538e-01,  2.3883e-02, -1.2363e-01, -3.4986e-01,
#                         1.5775e-02,  2.4032e-02,  6.0918e-02, -1.7735e-01, -1.6314e-01,
#                        -2.6619e-01,  2.6953e-01,  2.5536e-01,  4.4449e-01, -7.4156e-01,
#                        -8.5469e-01, -2.6712e-01,  6.0985e-02, -4.4866e-01, -4.7821e-01,
#                        -4.8238e-01,  1.6657e-01,  4.5558e-02, -5.8210e-01, -7.8798e-01,
#                        -6.8449e-01, -2.4942e-01,  8.8568e-02, -4.7440e-01],
#                       [ 6.1949e-02, -6.4738e-01, -3.0502e-01, -6.4443e-01, -5.4411e-01,
#                        -7.9690e-01, -6.7007e-01,  3.1756e-01, -1.9990e-02, -6.9045e-01,
#                         2.5775e-01, -3.5716e-01, -3.7175e-01, -5.0273e-01, -4.1913e-01,
#                         8.0200e-01,  1.4405e-02,  6.5225e-02, -4.8472e-01, -6.0643e-01,
#                         4.1246e-03, -8.6274e-01,  1.0467e-01, -2.0865e-01,  6.5380e-02,
#                         2.3548e-01,  1.8156e-01, -2.9120e-02,  1.3438e-01,  2.9915e-02,
#                         2.0418e-01, -3.3266e-02, -6.5260e-02,  3.3375e-02,  1.4222e-01,
#                        -2.8323e-02, -4.9785e-02, -2.9441e-01, -2.7315e-01,  3.9222e-01,
#                        -3.2715e-01, -4.5851e-01, -6.0577e-01, -2.4241e-01, -1.7978e-02,
#                         4.0340e-01, -2.9901e-01,  2.7928e-01,  1.1286e-01,  2.1227e-01,
#                         5.0179e-02, -3.6003e-01,  6.0937e-02, -6.3263e-01, -5.4513e-02,
#                        -2.3702e-01, -6.2713e-01, -2.1070e-01, -4.2695e-01, -4.8890e-01,
#                        -5.0732e-01, -4.1756e-01,  1.3417e-01, -5.2760e-01],
#                       [-1.7761e-01,  9.6356e-02, -6.5994e-01, -4.6720e-02, -6.8593e-01,
#                         7.7823e-02,  1.3787e-01, -4.8810e-01,  1.1919e-01,  1.4096e-01,
#                        -5.2305e-01, -2.0210e-01, -8.8648e-01,  3.5984e-01, -5.4315e-01,
#                        -1.1924e-01, -5.5811e-01, -7.1443e-01, -4.2865e-02,  2.3133e-01,
#                         1.7046e-01, -6.3099e-02, -7.0089e-01,  2.6680e-02, -5.0176e-01,
#                        -5.1418e-01, -3.6266e-02,  2.6807e-01,  1.8672e-01, -1.6516e-01,
#                        -6.7800e-02, -7.5915e-02,  1.4137e-01, -9.4099e-01, -4.0782e-01,
#                        -9.4789e-01, -6.2050e-01,  3.3676e-01,  3.1824e-01,  2.6547e-02,
#                         2.0685e-02, -7.8840e-01,  1.7648e-01, -6.5696e-01,  1.2191e-01,
#                         2.0849e-01, -1.4008e-01, -2.3904e-01, -1.5842e-01, -6.8006e-01,
#                        -5.7310e-02,  2.5685e-01,  8.7661e-03,  2.1262e-01,  3.2043e-02,
#                        -4.0524e-01,  2.3983e-01,  3.8835e-01, -5.5085e-01,  8.3802e-03,
#                        -5.3459e-01,  1.0090e-01, -8.2698e-01,  4.7627e-02],
#                       [-4.2817e-01,  2.7939e-01,  7.3348e-02, -9.4674e-01, -5.8204e-02,
#                         4.6188e-01, -1.6024e-01,  1.6540e-01,  3.9255e-02, -9.3008e-01,
#                        -1.2838e-01,  7.4674e-02,  2.7805e-01, -3.1224e-01, -8.5400e-01,
#                        -2.5436e-01,  1.8299e-01, -4.7494e-01, -3.7625e-01, -6.1657e-01,
#                        -5.9049e-01,  3.5973e-02, -7.2242e-02,  6.1929e-02, -1.0527e+00,
#                         7.1975e-02, -5.6686e-02, -1.1096e-01, -6.7199e-01,  8.1829e-02,
#                         2.2141e-02, -7.2161e-02,  5.2237e-01,  1.2408e-01,  1.4436e-01,
#                         2.6740e-01, -5.5740e-01, -4.8973e-01, -1.1027e-01,  1.9224e-01,
#                        -4.2229e-01, -5.0346e-01, -8.3595e-01,  8.1422e-02,  1.3016e-01,
#                        -4.7503e-01, -1.9746e-01, -6.3394e-01, -1.5162e-01, -4.0213e-02,
#                         4.9693e-02, -4.9371e-01, -5.7113e-02, -6.1230e-01,  1.5198e-03,
#                        -2.9753e-01, -8.3232e-01, -4.8834e-01,  7.4955e-02,  3.3620e-01,
#                        -5.4860e-02, -3.2725e-02, -1.8781e-01,  2.7903e-01],
#                       [ 1.4866e-01, -1.8643e-01, -3.3918e-01,  1.2020e-02, -5.3497e-01,
#                         1.8337e-01,  1.3328e-01,  2.0748e-01, -1.3963e-01, -5.0310e-02,
#                        -4.9777e-01,  1.9397e-01, -4.5142e-01, -5.1024e-01,  6.5573e-02,
#                        -8.5600e-02,  2.0006e-01, -7.6204e-01, -3.4912e-01,  1.6077e-01,
#                        -1.8951e-01,  1.3188e-01,  1.6892e-01,  1.3578e-01, -6.7309e-01,
#                        -5.2747e-01, -1.0119e-01, -2.3067e-01, -3.5657e-01,  4.7812e-02,
#                        -3.7341e-01, -9.3006e-02, -2.1434e-01,  8.6471e-02, -5.2836e-01,
#                        -6.6478e-01, -3.6900e-01, -5.5252e-01, -4.1989e-01, -3.8438e-01,
#                         1.2482e-01, -4.0438e-01,  4.8764e-02,  3.6227e-01, -1.5514e-01,
#                        -4.1495e-01,  2.4714e-01, -6.6152e-01, -5.0965e-01, -4.7901e-01,
#                        -8.7252e-01,  2.4251e-02, -2.1532e-02, -7.5044e-01, -3.9711e-01,
#                        -4.8134e-01,  4.0819e-02, -1.8146e-01, -6.1131e-01, -4.0159e-02,
#                         2.6438e-01, -1.5320e-01, -8.1103e-01,  2.5871e-01],
#                       [-3.3511e-01, -4.9820e-01,  2.2550e-01,  1.8486e-01,  5.7888e-01,
#                        -3.9663e-01, -7.6049e-01, -2.5739e-01, -5.1304e-02,  3.0250e-01,
#                        -3.2660e-01, -4.7423e-01,  2.0293e-01, -2.2190e-01, -3.3530e-01,
#                        -1.1506e-01, -7.0430e-01,  1.7312e-01,  1.3124e-01, -4.8834e-01,
#                         2.8494e-02, -4.1378e-01, -6.0698e-01, -6.3531e-01,  8.2158e-02,
#                        -5.1200e-01,  1.3171e-02, -1.1058e-01,  3.1264e-01, -6.7799e-01,
#                        -4.7897e-01, -8.6715e-02,  4.9453e-02, -6.1707e-01, -5.8720e-01,
#                         2.1852e-01, -9.6982e-03,  1.9571e-01, -4.0573e-01, -2.0207e-01,
#                        -1.8160e-01,  2.3077e-01, -8.1341e-02, -3.8139e-01, -7.6072e-01,
#                         3.0794e-01, -4.4180e-01,  2.4031e-02, -3.4268e-01,  1.5317e-01,
#                        -8.2815e-02, -3.7186e-01,  8.9211e-02, -1.6701e-01, -6.3778e-01,
#                         2.8088e-01, -3.2693e-01, -1.5735e-01,  1.6782e-01, -4.1951e-01,
#                        -4.7621e-01, -1.0594e-01,  1.7616e-01, -7.3036e-01],
#                       [ 1.3533e-01,  3.5469e-01,  5.1355e-01, -7.5894e-01, -4.9257e-01,
#                        -5.2794e-01,  3.2002e-01, -6.9275e-01, -8.7747e-02,  7.4387e-02,
#                         1.6724e-01, -1.9529e-01, -1.4275e-01, -5.3566e-01, -6.9906e-01,
#                        -2.7600e-01,  8.3129e-02,  1.7022e-01, -4.5531e-01,  4.1145e-01,
#                         1.4350e-01, -1.9666e-01, -2.7130e-01,  1.5028e-02,  3.5684e-02,
#                        -1.6693e-01,  8.3499e-02,  7.7030e-02, -7.1596e-01,  1.8418e-01,
#                         2.8906e-01,  6.7467e-02, -3.3054e-01,  1.3141e-01, -1.6364e-02,
#                        -3.2195e-01, -5.4877e-01, -4.4350e-01, -6.7664e-01, -6.3788e-01,
#                         8.2903e-01,  2.9474e-01, -5.1420e-01, -1.1355e-01, -4.3810e-01,
#                        -4.3485e-01, -4.4914e-01,  7.3402e-02, -4.9733e-01, -5.2168e-01,
#                        -2.6588e-02, -5.7114e-01,  8.9988e-02, -7.7133e-01,  1.2087e-01,
#                        -5.0048e-01,  2.3618e-01, -6.7608e-01, -7.1281e-01, -7.7985e-01,
#                        -7.5689e-01,  3.5633e-01,  5.0490e-02,  1.4805e-01],
#                       [-1.0174e+00,  1.4640e-01, -1.0737e-01, -7.0335e-01, -7.3548e-01,
#                        -9.6535e-01,  6.5195e-02, -1.7872e-01,  4.9998e-02, -4.0667e-01,
#                         2.4245e-01, -6.5343e-01,  1.2717e-01,  1.5191e-01, -4.0358e-01,
#                        -8.7130e-02, -6.7597e-01,  5.4893e-02,  1.9771e-01, -3.8421e-01,
#                         1.2607e-01,  2.2687e-01, -5.0148e-01, -7.6173e-01,  1.4808e-02,
#                        -6.0088e-01, -5.6379e-02, -2.3853e-01, -4.0845e-01,  2.1966e-01,
#                         1.8754e-01,  4.6895e-03, -2.0324e-01, -9.4466e-01,  1.5677e-01,
#                        -5.2188e-02, -8.4051e-01,  1.4199e-01,  2.3144e-01, -8.3400e-02,
#                        -4.5332e-01, -8.5423e-02, -6.5200e-01, -2.8180e-01,  1.3417e-01,
#                         1.8278e-01, -7.3264e-01, -4.4543e-01,  1.3062e-03,  1.7572e-01,
#                         6.4355e-02,  2.0456e-01, -2.9868e-02,  1.4151e-01,  7.7934e-02,
#                         2.0396e-01, -3.6688e-01, -7.8669e-01,  1.6784e-01,  2.2017e-01,
#                        -5.4375e-01,  2.2149e-01, -7.8555e-01, -8.0611e-01]])),
#              ('fc4.bias',
#               tensor([-0.2364,  0.4433,  0.0067,  0.0846,  0.2818,  0.2309, -0.0673,  0.1891,
#                       -0.0981,  0.2143]))])
